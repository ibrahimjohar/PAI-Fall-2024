# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold 
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

dataset = pd.read_csv("heart.csv")

dataset
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
X = dataset.drop('target', axis=1)
Y = dataset['target']

X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal
# 0   2     3
# 1   0     3
# 2   0     3
# 3   1     3
# 4   3     2

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)
scaled_X
# Out:
# array([[-0.26843658,  0.66150409, -0.91575542, ...,  0.99543334,
#          1.20922066,  1.08985168],
#        [-0.15815703,  0.66150409, -0.91575542, ..., -2.24367514,
#         -0.73197147,  1.08985168],
#        [ 1.71659547,  0.66150409, -0.91575542, ..., -2.24367514,
#         -0.73197147,  1.08985168],
#        ...,
#        [-0.81983438,  0.66150409, -0.91575542, ..., -0.6241209 ,
#          0.23862459, -0.52212231],
#        [-0.4889957 , -1.51170646, -0.91575542, ...,  0.99543334,
#         -0.73197147, -0.52212231],
#        [-0.04787747,  0.66150409, -0.91575542, ..., -0.6241209 ,
#          0.23862459,  1.08985168]])

# %%
X_train,X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
predictions = knn.predict(X_test)
accuracy_score(Y_test, predictions)
# Out:
# 0.9902597402597403

# %%
confusion_matrix(Y_test, predictions)
# Out:
# array([[145,   0],
#        [  3, 160]])

# %%
accuracies = {}
for i in range(1,251):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, Y_train)
    predictions = knn.predict(X_test)
    accuracies[i] = accuracy_score(Y_test, predictions)

neighborMAX = max(accuracies, key=accuracies.get)
neighborMIN = min(accuracies, key=accuracies.get)

print(neighborMAX, "neighbors provide max accuracy: ", accuracies[neighborMAX])
print(neighborMIN, "neighbors provide min accuracy: ", accuracies[neighborMIN])
# Out:
# 1 neighbors provide max accuracy:  0.9902597402597403
# 250 neighbors provide min accuracy:  0.6558441558441559

# %% [markdown]
# Q2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold 
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

dataset = pd.read_csv("heart.csv")

X = dataset.drop('target', axis=1)
Y = dataset['target']

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

accuracies = {}
knn = KNeighborsClassifier(n_neighbors=1)
for i in range(1,11):
    X_train, X_test, Y_train, Y_test = train_test_split(scaled_X, Y, test_size=0.3, random_state=i)
    knn.fit(X_train, Y_train)
    accuracies[i] = accuracy_score(Y_test, knn.predict(X_test))
    
seedMAX = max(accuracies, key=accuracies.get)
seedMIN = min(accuracies, key=accuracies.get)

print(seedMAX, "seed value provide max accuracy: ", accuracies[seedMAX])
print(seedMIN, "seed value provide min accuracy: ", accuracies[seedMIN])
# Out:
# 4 seed value provide max accuracy:  1.0
# 10 seed value provide min accuracy:  0.9512987012987013

# %% [markdown]
# Q3

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

df = pd.read_csv("derma.csv")

df.head()
# Out:
#    Unnamed: 0  erythema  scaling  definite-borders  itching  \
# 0           0         2        2                 0        3
# 1           1         3        3                 3        2
# 2           2         2        1                 2        3
# 3           3         2        2                 2        0
# 4           4         2        3                 2        2
#
#    koebner phenomenon  polygonal papules  follicular papules  \
# 0                   0                  0                   0
# 1                   1                  0                   0
# 2                   1                  3                   0
# 3                   0                  0                   0
# 4                   2                  2                   0
#
#    oral-mucosal involvement  knee elbow involvement  ...  \
# 0                         0                       1  ...
# 1                         0                       1  ...
# 2                         3                       0  ...
# ...

# %%
X = df.values[:, :35]
y = df.values[:, 35]

df.dropna()

display(X.shape, y.shape)
print("Number of NaN values in the dataset:", df.isna().sum().sum())
df = df.dropna(subset=['age'])
print("Number of NaN values in the dataset:", df.isna().sum().sum())
print(f"Are there any NaNs in X? {np.isnan(X).any()}")
print(f"Are there any NaNs in y? {np.isnan(y).any()}")
# Check if there are any infinite values in X or y
print(f"Are there any infinities in X? {np.isinf(X).any()}")
print(f"Are there any infinities in y? {np.isinf(y).any()}")
# Out:
# (366, 35)
# (366,)
# Number of NaN values in the dataset: 8
# Number of NaN values in the dataset: 0
# Are there any NaNs in X? True
# Are there any NaNs in y? False
# Are there any infinities in X? False
# Are there any infinities in y? False

# %%
from sklearn.model_selection import KFold

kf = KFold(10, shuffle=True, random_state=727)

for i, (train_index, test_index) in enumerate(kf.split(X)):
    knn = KNeighborsClassifier(n_neighbors=3)
    knn.fit(X[train_index], y[train_index])
    predictions = knn.predict(X[test_index])
    print(f'Iteration {i+1}:\nConfusion Matrix')
    display(confusion_matrix(y[test_index], predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       5 for i, (train_index, test_index) in enumerate(kf.split(X)):
#       6     knn = KNeighborsClassifier(n_neighbors=3)
# ----> 7     knn.fit(X[train_index], y[train_index])
#       8     predictions = knn.predict(X[test_index])
#       9     print(f'Iteration {i+1}:\nConfusion Matrix')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...
